# %%
# %autosave 0
import os

runs_dir = '/home/gabi/diplomka/results/with_ref_5/2021-20-07_23-26-03/reinforce-runs'

# %%
import json

with open(os.path.join(runs_dir, 'run_497_features_model_orig_epoch-9.json'), 'rb') as f:
    res = json.load(f)
res.keys()
# Out:
# dict_keys(['regret_validation', 'regret_test', 'runtime'])

# %%
import pandas as pd

pd.DataFrame(res)
# Out:
#      regret_validation  regret_test       runtime
# 0             0.089877     0.086939  3.278185e+03
# 1             0.089877     0.086939  4.200537e+03
# 2             0.089877     0.086939  5.704944e+03
# 3             0.023771     0.020199  7.042099e+03
# 4             0.023771     0.020199  8.846069e+03
# ..                 ...          ...           ...
# 671           0.000000     0.000835  1.486738e+06
# 672           0.000000     0.000835  1.489803e+06
# 673           0.000000     0.000835  1.494939e+06
# 674           0.000000     0.000835  1.499573e+06
# 675           0.000000     0.000835  1.501390e+06
#
# [676 rows x 3 columns]

# %%
def process_one_run(file):
    with open(file, 'rb') as f:
        res = json.load(f)
        
    res_df = pd.DataFrame(res)
    res_df['name'] = os.path.basename(file).replace('.json', '')
    
    return res_df

# %%
import glob

info_9_runs = glob.glob(os.path.join(runs_dir, 'run_*_features_model_orig_epoch-9.json'))
info_9_dfs = [process_one_run(g) for g in info_9_runs]
info_9_dfs = pd.concat(info_9_dfs, axis=0)
info_9_dfs
# Out:
#      regret_validation  regret_test       runtime  \
# 0             0.041867     0.040832  1.023246e+03
# 1             0.025674     0.022970  2.459435e+03
# 2             0.025674     0.022970  3.813060e+03
# 3             0.025674     0.022970  5.254597e+03
# 4             0.025674     0.022970  6.193464e+03
# ..                 ...          ...           ...
# 666           0.001603     0.002304  1.489216e+06
# 667           0.001603     0.002304  1.491055e+06
# 668           0.001603     0.002304  1.493017e+06
# 669           0.001603     0.002304  1.498142e+06
# 670           0.001603     0.002304  1.503316e+06
#
#                                     name
# 0    run_100_features_model_orig_epoch-9
# 1    run_100_features_model_orig_epoch-9
# 2    run_100_features_model_orig_epoch-9
# 3    run_100_features_model_orig_epoch-9
# 4    run_100_features_model_orig_epoch-9
# ..                                   ...
# 666  run_296_features_model_orig_epoch-9
# 667  run_296_features_model_orig_epoch-9
# 668  run_296_features_model_orig_epoch-9
# 669  run_296_features_model_orig_epoch-9
# 670  run_296_features_model_orig_epoch-9
#
# [302019 rows x 4 columns]

# %%
arch_9_runs = glob.glob(os.path.join(runs_dir, 'run_*_features_model_ref_epoch-9.json'))
arch_9_dfs = [process_one_run(g) for g in arch_9_runs]
arch_9_dfs = pd.concat(arch_9_dfs, axis=0)
arch_9_dfs
# Out:
#      regret_validation  regret_test       runtime  \
# 0             0.020199     0.018429  1.462185e+03
# 1             0.020199     0.018429  3.019828e+03
# 2             0.013822     0.013021  4.320425e+03
# 3             0.013822     0.013021  6.614972e+03
# 4             0.013822     0.013021  9.988819e+03
# ..                 ...          ...           ...
# 527           0.000000     0.000835  1.489868e+06
# 528           0.000000     0.000835  1.493906e+06
# 529           0.000000     0.000835  1.496181e+06
# 530           0.000000     0.000835  1.498772e+06
# 531           0.000000     0.000835  1.502862e+06
#
#                                    name
# 0    run_100_features_model_ref_epoch-9
# 1    run_100_features_model_ref_epoch-9
# 2    run_100_features_model_ref_epoch-9
# 3    run_100_features_model_ref_epoch-9
# 4    run_100_features_model_ref_epoch-9
# ..                                  ...
# 527  run_295_features_model_ref_epoch-9
# 528  run_295_features_model_ref_epoch-9
# 529  run_295_features_model_ref_epoch-9
# 530  run_295_features_model_ref_epoch-9
# 531  run_295_features_model_ref_epoch-9
#
# [288525 rows x 4 columns]

# %%
rounded_run = info_9_dfs['runtime'].round(decimals=-3)
rounded_run[rounded_run == 2000]
# Out:
# 1    2000.0
# 1    2000.0
# 0    2000.0
# 0    2000.0
# 0    2000.0
#       ...
# 1    2000.0
# 0    2000.0
# 1    2000.0
# 0    2000.0
# 0    2000.0
# Name: runtime, Length: 284, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

cutoff=False

sns.set()

info_29_dfs['rounded_runtime'] = info_29_dfs['runtime'].round(decimals=-4)
arch_29_dfs['rounded_runtime'] = arch_29_dfs['runtime'].round(decimals=-4)

plt.figure()
sns.lineplot(data=info_9_dfs, x='rounded_runtime', y='regret_validation',
#             label='info-NAS, 10 epochs')
             label='our model, 10 epochs')
sns.lineplot(data=arch_9_dfs, x='rounded_runtime', y='regret_validation',
             label='arch2vec, 10 epochs')

sns.lineplot(data=info_29_dfs, x='rounded_runtime', y='regret_validation',
#             label='info-NAS, 30 epochs')
             label='our model, 10 epochs')
sns.lineplot(data=arch_29_dfs, x='rounded_runtime', y='regret_validation',
             label='arch2vec, 30 epochs')

plt.xscale('log')
plt.yscale('log')
if cutoff:
    plt.xlim(left=5e5, right=1.5e6)
else:
    plt.xlim(right=1.5e6)

save_path = '/home/gabi/diplomka/neurips/paper/diplomka_to_neurips/img/'
    
plt.xlabel('Runtime')
plt.ylabel('Validation regret')
plt.title(f"Comparison of 500 REINFORCE runs - validation{' (detail)' if cutoff else ''}")
plt.tight_layout()
plt.savefig(os.path.join(save_path, f'valid_reinf{"_cutoff" if cutoff else ""}.png'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

cutoff=False

sns.set()

info_29_dfs['rounded_runtime'] = info_29_dfs['runtime'].round(decimals=-4)
arch_29_dfs['rounded_runtime'] = arch_29_dfs['runtime'].round(decimals=-4)

plt.figure()
sns.lineplot(data=info_9_dfs, x='rounded_runtime', y='regret_test',
             label='our model, 10 epochs')
sns.lineplot(data=arch_9_dfs, x='rounded_runtime', y='regret_test',
             label='arch2vec, 10 epochs')

sns.lineplot(data=info_29_dfs, x='rounded_runtime', y='regret_test',
             label='our model, 30 epochs')
sns.lineplot(data=arch_29_dfs, x='rounded_runtime', y='regret_test',
             label='arch2vec, 30 epochs')

plt.xscale('log')
plt.yscale('log')
if cutoff:
    plt.xlim(left=5e5, right=1.5e6)
else:
    plt.xlim(right=1.5e6)
    
plt.xlabel('Runtime')
plt.ylabel('Test regret')
plt.title(f"Comparison of 500 REINFORCE runs - test{' (detail)' if cutoff else ''}")
plt.tight_layout()
plt.savefig(os.path.join(save_path, f'test_reinf{"_cutoff" if cutoff else ""}.png'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
info_29_runs = glob.glob(os.path.join(runs_dir, 'run_*_features_model_orig_epoch-29.json'))
info_29_dfs = [process_one_run(g) for g in info_29_runs]
info_29_dfs = pd.concat(info_29_dfs, axis=0)
info_29_dfs
# Out:
#      regret_validation  regret_test       runtime  \
# 0             0.034221     0.031317  1.032803e+03
# 1             0.014690     0.009014  5.112762e+03
# 2             0.014690     0.009014  7.138725e+03
# 3             0.014690     0.009014  7.985999e+03
# 4             0.014690     0.009014  9.654629e+03
# ..                 ...          ...           ...
# 624           0.000000     0.000835  1.490958e+06
# 625           0.000000     0.000835  1.493497e+06
# 626           0.000000     0.000835  1.495017e+06
# 627           0.000000     0.000835  1.498178e+06
# 628           0.000000     0.000835  1.500429e+06
#
#                                      name
# 0    run_100_features_model_orig_epoch-29
# 1    run_100_features_model_orig_epoch-29
# 2    run_100_features_model_orig_epoch-29
# 3    run_100_features_model_orig_epoch-29
# 4    run_100_features_model_orig_epoch-29
# ..                                    ...
# 624  run_296_features_model_orig_epoch-29
# 625  run_296_features_model_orig_epoch-29
# 626  run_296_features_model_orig_epoch-29
# 627  run_296_features_model_orig_epoch-29
# 628  run_296_features_model_orig_epoch-29
#
# [306868 rows x 4 columns]

# %%
arch_29_runs = glob.glob(os.path.join(runs_dir, 'run_*_features_model_ref_epoch-29.json'))
arch_29_dfs = [process_one_run(g) for g in arch_29_runs]
arch_29_dfs = pd.concat(arch_29_dfs, axis=0)
arch_29_dfs
# Out:
#      regret_validation  regret_test       runtime  \
# 0             0.019498     0.017495  2.293862e+03
# 1             0.019498     0.017495  5.620721e+03
# 2             0.016126     0.015425  7.655421e+03
# 3             0.016126     0.015425  1.037525e+04
# 4             0.016126     0.015425  1.380374e+04
# ..                 ...          ...           ...
# 603           0.000000     0.000835  1.492333e+06
# 604           0.000000     0.000835  1.494520e+06
# 605           0.000000     0.000835  1.496930e+06
# 606           0.000000     0.000835  1.499522e+06
# 607           0.000000     0.000835  1.501346e+06
#
#                                     name
# 0    run_100_features_model_ref_epoch-29
# 1    run_100_features_model_ref_epoch-29
# 2    run_100_features_model_ref_epoch-29
# 3    run_100_features_model_ref_epoch-29
# 4    run_100_features_model_ref_epoch-29
# ..                                   ...
# 603  run_296_features_model_ref_epoch-29
# 604  run_296_features_model_ref_epoch-29
# 605  run_296_features_model_ref_epoch-29
# 606  run_296_features_model_ref_epoch-29
# 607  run_296_features_model_ref_epoch-29
#
# [292705 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

info_29_dfs['rounded_runtime'] = info_29_dfs['runtime'].round(decimals=-4)
arch_29_dfs['rounded_runtime'] = arch_29_dfs['runtime'].round(decimals=-4)

plt.figure()
sns.lineplot(data=info_29_dfs, x='rounded_runtime', y='regret_validation')
sns.lineplot(data=arch_29_dfs, x='rounded_runtime', y='regret_validation')

plt.xscale('log')
plt.yscale('log')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

info_29_dfs['rounded_runtime'] = info_29_dfs['runtime'].round(decimals=-4)
arch_29_dfs['rounded_runtime'] = arch_29_dfs['runtime'].round(decimals=-4)

plt.figure()
sns.lineplot(data=info_29_dfs, x='rounded_runtime', y='regret_test')
sns.lineplot(data=arch_29_dfs, x='rounded_runtime', y='regret_test')

plt.xscale('log')
plt.yscale('log')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
