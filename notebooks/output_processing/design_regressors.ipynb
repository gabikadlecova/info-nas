# %%
dir_name = '/home/gabi/diplomka/neurips/paper/regressors/'

# %%
import os

os.listdir(dir_name)
# Out:
# ['initial_tests',
#  'rf_10000_0_features-original_training_arch2vec_epochs-8.pt',
#  'rf_10000_0_features_model_orig_epoch-29.pt',
#  'rf_10000_0_features_model_ref_epoch-29.pt',
#  'rf_10000_1_features-original_training_arch2vec_epochs-8.pt',
#  'rf_10000_1_features_model_orig_epoch-29.pt',
#  'rf_10000_1_features_model_ref_epoch-29.pt',
#  'rf_10000_2_features-original_training_arch2vec_epochs-8.pt',
#  'rf_10000_2_features_model_orig_epoch-29.pt',
#  'rf_10000_2_features_model_ref_epoch-29.pt',
#  'rf_10000_3_features-original_training_arch2vec_epochs-8.pt',
#  'rf_100_4_features_model_orig_epoch-29.pt',
#  'rf_100_4_features_model_ref_epoch-29.pt',
#  'rf_100_5_features-original_training_arch2vec_epochs-8.pt',
#  'rf_100_5_features_model_orig_epoch-29.pt',
#  'rf_100_5_features_model_ref_epoch-29.pt',
#  'rf_100_6_features-original_training_arch2vec_epochs-8.pt',
#  'rf_100_6_features_model_orig_epoch-29.pt',
#  'rf_100_6_features_model_ref_epoch-29.pt',
#  'rf_100_7_features-original_training_arch2vec_epochs-8.pt',
#  'rf_100_7_features_model_orig_epoch-29.pt',
#  'rf_100_7_features_model_ref_epoch-29.pt',
#  'rf_100_8_features_model_orig_epoch-29.pt',
#  'rf_100_8_features_model_ref_epoch-29.pt',
#  'rf_100_9_features-original_training_arch2vec_epochs-8.pt',
#  'rf_100_9_features_model_orig_epoch-29.pt',
#  'rf_100_9_features_model_ref_epoch-29.pt',
#  'rf_250_0_features-original_training_arch2vec_epochs-8.pt',
#  'rf_250_0_features_model_orig_epoch-29.pt',
#  'rf_250_0_features_model_ref_epoch-29.pt',
#  'rf_250_1_features-original_training_arch2vec_epochs-8.pt',
#  'rf_250_1_features_model_orig_epoch-29.pt',
#  'rf_250_1_features_model_ref_epoch-29.pt',
#  'rf_10000_3_features_model_orig_epoch-29.pt',
#  'rf_10000_8_features-original_training_arch2vec_epochs-8.pt',
#  'rf_1000_3_features_model_orig_epoch-29.pt',
#  'rf_100_0_features_model_orig_epoch-29.pt',
#  'rf_100_4_features-original_training_arch2vec_epochs-8.pt',
#  'rf_100_8_features-original_training_arch2vec_epochs-8.pt',
#  'rf_250_2_features-original_training_arch2vec_epochs-8.pt',
#  'rf_250_6_features-original_training_arch2vec_epochs-8.pt',
#  'rf_600_0_features-original_training_arch2vec_epochs-8.pt',
#  'rf_600_4_features-original_training_arch2vec_epochs-8.pt',
#  'rf_250_2_features_model_orig_epoch-29.pt',
#  'rf_250_2_features_model_ref_epoch-29.pt',
#  'rf_250_3_features-original_training_arch2vec_epochs-8.pt',
#  'rf_250_3_features_model_orig_epoch-29.pt',
#  'rf_250_3_features_model_ref_epoch-29.pt',
#  'rf_250_4_features-original_training_arch2vec_epochs-8.pt',
#  'rf_250_4_features_model_orig_epoch-29.pt',
#  'rf_250_4_features_model_ref_epoch-29.pt',
#  'rf_250_5_features-original_training_arch2vec_epochs-8.pt',
#  'rf_250_5_features_model_orig_epoch-29.pt',
#  'rf_250_5_features_model_ref_epoch-29.pt',
#  'rf_250_6_features_model_orig_epoch-29.pt',
#  'rf_250_6_features_model_ref_epoch-29.pt',
#  'rf_250_7_features-original_training_arch2vec_epochs-8.pt',
#  'rf_250_7_features_model_orig_epoch-29.pt',
#  'rf_250_7_features_model_ref_epoch-29.pt',
#  'rf_250_8_features-original_training_arch2vec_epochs-8.pt',
#  'rf_250_8_features_model_orig_epoch-29.pt',
#  'rf_250_8_features_model_ref_epoch-29.pt',
#  'rf_250_9_features-original_training_arch2vec_epochs-8.pt',
#  'rf_250_9_features_model_orig_epoch-29.pt',
#  'rf_250_9_features_model_ref_epoch-29.pt',
#  'rf_600_0_features_model_orig_epoch-29.pt',
#  'rf_600_0_features_model_ref_epoch-29.pt',
#  'rf_600_1_features-original_training_arch2vec_epochs-8.pt',
#  'rf_600_1_features_model_orig_epoch-29.pt',
#  'rf_600_1_features_model_ref_epoch-29.pt',
#  'rf_600_2_features-original_training_arch2vec_epochs-8.pt',
#  'rf_600_2_features_model_orig_epoch-29.pt',
#  'rf_600_2_features_model_ref_epoch-29.pt',
#  'rf_600_3_features-original_training_arch2vec_epochs-8.pt',
#  'rf_600_3_features_model_orig_epoch-29.pt',
#  'rf_600_3_features_model_ref_epoch-29.pt',
#  'rf_600_4_features_model_orig_epoch-29.pt',
#  'rf_600_4_features_model_ref_epoch-29.pt',
#  'rf_600_5_features-original_training_arch2vec_epochs-8.pt',
#  'rf_600_5_features_model_orig_epoch-29.pt',
#  'rf_600_5_features_model_ref_epoch-29.pt',
#  'rf_600_6_features-original_training_arch2vec_epochs-8.pt',
#  'rf_600_6_features_model_orig_epoch-29.pt',
#  'rf_600_6_features_model_ref_epoch-29.pt',
#  'rf_600_7_features-original_training_arch2vec_epochs-8.pt',
#  'rf_600_7_features_model_orig_epoch-29.pt',
#  'rf_600_7_features_model_ref_epoch-29.pt',
#  'rf_600_8_features-original_training_arch2vec_epochs-8.pt',
#  'rf_600_8_features_model_orig_epoch-29.pt',
#  'rf_600_8_features_model_ref_epoch-29.pt',
#  'rf_600_9_features-original_training_arch2vec_epochs-8.pt',
#  'rf_600_9_features_model_orig_epoch-29.pt',
#  'rf_600_9_features_model_ref_epoch-29.pt',
#  'rf_tune_10000_4_features-original_training_arch2vec_epochs-8.pt',
#  'rf_tune_10000_4_features_model_orig_epoch-29.pt',
#  'rf_100_0_features_model_ref_epoch-29.pt',
#  'rf_100_1_features-original_training_arch2vec_epochs-8.pt',
#  'rf_100_1_features_model_orig_epoch-29.pt',
#  'rf_100_1_features_model_ref_epoch-29.pt',
#  'rf_100_2_features-original_training_arch2vec_epochs-8.pt',
#  'rf_100_2_features_model_orig_epoch-29.pt',
#  'rf_100_2_features_model_ref_epoch-29.pt',
#  'rf_100_3_features-original_training_arch2vec_epochs-8.pt',
#  'rf_100_3_features_model_orig_epoch-29.pt',
#  'rf_100_3_features_model_ref_epoch-29.pt',
#  'rf_1000_3_features_model_ref_epoch-29.pt',
#  'rf_1000_4_features-original_training_arch2vec_epochs-8.pt',
#  'rf_1000_4_features_model_orig_epoch-29.pt',
#  'rf_1000_4_features_model_ref_epoch-29.pt',
#  'rf_1000_5_features-original_training_arch2vec_epochs-8.pt',
#  'rf_1000_5_features_model_orig_epoch-29.pt',
#  'rf_1000_5_features_model_ref_epoch-29.pt',
#  'rf_1000_6_features-original_training_arch2vec_epochs-8.pt',
#  'rf_1000_6_features_model_orig_epoch-29.pt',
#  'rf_1000_6_features_model_ref_epoch-29.pt',
#  'rf_1000_7_features-original_training_arch2vec_epochs-8.pt',
#  'rf_1000_7_features_model_orig_epoch-29.pt',
#  'rf_1000_7_features_model_ref_epoch-29.pt',
#  'rf_1000_8_features-original_training_arch2vec_epochs-8.pt',
#  'rf_1000_8_features_model_orig_epoch-29.pt',
#  'rf_1000_8_features_model_ref_epoch-29.pt',
#  'rf_1000_9_features-original_training_arch2vec_epochs-8.pt',
#  'rf_1000_9_features_model_orig_epoch-29.pt',
#  'rf_1000_9_features_model_ref_epoch-29.pt',
#  'rf_100_0_features-original_training_arch2vec_epochs-8.pt',
#  'rf_10000_3_features_model_ref_epoch-29.pt',
#  'rf_10000_4_features-original_training_arch2vec_epochs-8.pt',
#  'rf_10000_4_features_model_orig_epoch-29.pt',
#  'rf_10000_4_features_model_ref_epoch-29.pt',
#  'rf_10000_5_features-original_training_arch2vec_epochs-8.pt',
#  'rf_10000_5_features_model_orig_epoch-29.pt',
#  'rf_10000_5_features_model_ref_epoch-29.pt',
#  'rf_10000_6_features-original_training_arch2vec_epochs-8.pt',
#  'rf_10000_6_features_model_orig_epoch-29.pt',
#  'rf_10000_6_features_model_ref_epoch-29.pt',
#  'rf_10000_7_features-original_training_arch2vec_epochs-8.pt',
#  'rf_10000_7_features_model_orig_epoch-29.pt',
#  'rf_10000_7_features_model_ref_epoch-29.pt',
#  'rf_10000_8_features_model_orig_epoch-29.pt',
#  'rf_10000_8_features_model_ref_epoch-29.pt',
#  'rf_10000_9_features-original_training_arch2vec_epochs-8.pt',
#  'rf_10000_9_features_model_orig_epoch-29.pt',
#  'rf_10000_9_features_model_ref_epoch-29.pt',
#  'rf_1000_0_features-original_training_arch2vec_epochs-8.pt',
#  'rf_1000_0_features_model_orig_epoch-29.pt',
#  'rf_1000_0_features_model_ref_epoch-29.pt',
#  'rf_1000_1_features-original_training_arch2vec_epochs-8.pt',
#  'rf_1000_1_features_model_orig_epoch-29.pt',
#  'rf_1000_1_features_model_ref_epoch-29.pt',
#  'rf_1000_2_features-original_training_arch2vec_epochs-8.pt',
#  'rf_1000_2_features_model_orig_epoch-29.pt',
#  'rf_1000_2_features_model_ref_epoch-29.pt',
#  'rf_1000_3_features-original_training_arch2vec_epochs-8.pt']

# %%
def process_res_dict(path, seed, algo, model):
    with open(os.path.join(path, 'Test features - validation accuracy_metrics.txt'), 'r') as f:
        res_dict = {}
        for l in f:
            l = l.split(': ')
            key = l[0]
            val = l[1].replace('(', '').replace(')', '').split(', ')[0]

            res_dict[key] = float(val)
            
        res_dict['seed'] = seed
        res_dict['algo'] = algo
        res_dict['model'] = model
    
    return res_dict

# %%
import glob

res_df = []

for seed in range(1, 11):
    for algo in ['gp', 'svr', 'rf', 'rf1000', 'gb']:
        for model in ['ref', 'orig']:
            p = os.path.join(dir_name, f'{algo}_250_{seed}_features_model_{model}_epoch-29.pt')

            res = process_res_dict(p, seed, algo, model)
            res_df.append(res)

# %%
len(res_df)
# Out:
# 100

# %%
import pandas as pd

res_dfs = pd.DataFrame(res_df)
results_table = res_dfs[['model', 'algo', 'RMSE', 'Pearson\'s r']].groupby(
    ['algo', 'model']).std().round(2)
print(results_table.to_latex())
# Out:
# \begin{tabular}{llrr}
# \toprule
#     &     &  RMSE &  Pearson's r \\
# algo & model &       &              \\
# \midrule
# gb & orig &  0.01 &         0.05 \\
#     & ref &  0.01 &         0.05 \\
# gp & orig &  0.02 &         0.09 \\
#     & ref &  0.02 &         0.09 \\
# rf & orig &  0.01 &         0.05 \\
#     & ref &  0.01 &         0.06 \\
# rf1000 & orig &  0.01 &         0.04 \\
#     & ref &  0.01 &         0.06 \\
# svr & orig &  0.01 &         0.13 \\
#     & ref &  0.01 &         0.05 \\
# \bottomrule
# \end{tabular}
